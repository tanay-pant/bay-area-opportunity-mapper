# %%
# import ting
import numpy as np
import pandas as pd
import geopandas as gpd

# %%
# load in the new dataframes we will be working with
crime = pd.read_csv('~/Downloads/opportunity mapper/cl_crime.csv')
rent_inc = pd.read_csv('~/Downloads/opportunity mapper/cl_rent_income.csv')
gdf_zip = gpd.read_file('~/Downloads/opportunity mapper/raw datasets/BayArea ShapeFile/s7888q.shp')

# %%
#things to do: 
# - see how many zip codes are in common with shapefile and rent_inc
# - merge the datasets (may need external help)
# - go from there

gdf_zip.head()
# Out:
#      ZIP    PO_NAME STATE        Area__       Length__  \
# 0  94558       NAPA    CA  1.231326e+10  995176.225313
# 1  95620      DIXON    CA  7.236950e+09  441860.201400
# 2  95476     SONOMA    CA  3.001414e+09  311318.546326
# 3  94559       NAPA    CA  1.194302e+09  359104.646602
# 4  94533  FAIRFIELD    CA  9.917861e+08  200772.556587
#
#                                             geometry
# 0  POLYGON ((-122.10329 38.51328, -122.10348 38.5...
# 1  POLYGON ((-121.65336 38.31339, -121.6934 38.31...
# 2  POLYGON ((-122.40684 38.15568, -122.40757 38.1...
# 3  POLYGON ((-122.29369 38.15524, -122.2985 38.15...
# 4  POLYGON ((-121.94748 38.30151, -121.94718 38.2...
